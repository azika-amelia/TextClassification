# %% [markdown]
# ## Results

# %%
import pandas as pd
import numpy as np
pd.options.display.max_colwidth = 1000
pd.options.display.max_rows = 3000

# %%
results = pd.read_csv('test_results.csv')

# %%
results
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     re
# ...

# %%
print results.iscorrect.sum(),'out of', results.shape[0], 'correctly predicted.'
# Out:
# 66 out of 88 correctly predicted.
